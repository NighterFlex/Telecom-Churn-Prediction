# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
#   Cell In[1], line 2
#     import numpy as
#                     ^
# SyntaxError: invalid syntax
